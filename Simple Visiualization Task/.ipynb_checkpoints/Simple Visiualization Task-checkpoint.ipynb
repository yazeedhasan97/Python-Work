# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (20,12)
# %matplotlib inline

import seaborn as sns
sns.set()

import os
import glob

# %%
path = os.
df = pd.read_csv("5.csv", index_col='tbl_dt')
df.head()
# Out:
#                cnt  msisdn_distinct  DEPOSIT_QTY   DEPOSIT_AMT  \
# tbl_dt
# 20200501  18280730         18104642      1170546  6.622057e+10
# 20200502  18280227         18109698      1053811  6.276058e+10
# 20200503  18285972         18114645      1049668  4.351233e+10
# 20200504  18300656         18124411      1166341  8.708915e+10
# 20200505  18306807         18132469      1153147  8.795469e+10
#
#           mom_withdrawal_qty  mom_withdrawal_amt  mom_bill_payment_qty  \
# tbl_dt
# 20200501              961729        6.501147e+10                650101
# 20200502              870534        5.783648e+10                600886
# 20200503              913641        4.873386e+10                587745
# 20200504              905715        1.078170e+11                606353
# 20200505              933720        8.692875e+10                577500
#
#           mom_bill_payment_amt  mom_send_qty  mom_send_amt  ...  \
# tbl_dt                                                      ...
# 20200501          1.192997e+10        565664  8.791491e+10  ...
# 20200502          1.028176e+10        498598  7.424463e+10  ...
# 20200503          8.772778e+09        471928  4.711670e+10  ...
# 20200504          1.135819e+10        522382  1.266834e+11  ...
# 20200505          1.076809e+10        553982  1.085119e+11  ...
#
#           gsm_active_days_qty  gsm_nta_amt  gsm_out_calls_qty  \
# tbl_dt
# 20200501              5612430   3769688471           29795848
# 20200502              5516960   3486912918           28124830
# 20200503              5647925   3608446852           29606597
# 20200504              5616062   3772508557           27811434
# 20200505              5636511   3813971381           32072208
#
#           gsm_uniq_out_bnum_qty  gsm_in_calls_qty  GSM_ACTIVE_DAYS_QTY  \
# tbl_dt
# 20200501               17925466          28385200              5612430
# 20200502               16919684          26836330              5516960
# 20200503               17748479          28278231              5647925
# 20200504               17080946          26502444              5616062
# 20200505               19636408          30646454              5636511
#
#           gsm_uniq_in_anum_qty  gsm_dat_vol_amt  gsm_me2u_received_qty  \
# tbl_dt
# 20200501              17014479     1.796723e+08                 106765
# 20200502              16083929     1.774981e+08                 100943
# 20200503              16880769     1.755631e+08                 109121
# 20200504              16210116     1.722097e+08                 101620
# 20200505              18694396     1.757783e+08                 105329
#
#           gsm_me2u_received_amt
# tbl_dt
# 20200501           1.374904e+08
# 20200502           1.171805e+08
# 20200503           1.187969e+08
# 20200504           1.239846e+08
# 20200505           1.363344e+08
#
# [5 rows x 27 columns]

# %%
plt.figure(figsize=(20,10))
plt.plot(df)
plt.yscale('log')
# plt.xscale('linear')
plt.xticks(rotation=15)
plt.legend(df.columns,loc='best')
plt.gca().get_xaxis().get_major_formatter().set_useOffset(False)
plt.savefig('C:\\Users\\GTS\\Desktop\\5.png', bbox_inches='tight')
plt.show()
