# %%
import tensorflow as tf
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt


# print(tf.__version__)
# tf.keras.mixed_precision.set_global_policy('mixed_float16')

# %%
def plot_series(time, series, format="-", start=0, end=None):
    """
    Visualizes time series data

    Args:
      time (array of int) - contains the time steps
      series (array of int) - contains the measurements for each time step
      format - line style when plotting the graph
      start - first time step to plot
      end - last time step to plot
    """

    # Setup dimensions of the graph figure
    plt.figure(figsize=(10, 6))
    
    if type(series) is tuple:

        for series_num in series:
            # Plot the time series data
            plt.plot(time[start:end], series_num[start:end], format)

    else:
      # Plot the time series data
      plt.plot(time[start:end], series[start:end], format)

    # Label the x-axis
    plt.xlabel("Time")

    # Label the y-axis
    plt.ylabel("Value")

    # Overlay a grid on the graph
    plt.grid(True)

    # Draw the graph on screen
    plt.show()

def trend(time, slope=0):
    """
    Generates synthetic data that follows a straight line given a slope value.

    Args:
      time (array of int) - contains the time steps
      slope (float) - determines the direction and steepness of the line

    Returns:
      series (array of float) - measurements that follow a straight line
    """

    # Compute the linear series given the slope
    series = slope * time

    return series

def seasonal_pattern(season_time):
    """
    Just an arbitrary pattern, you can change it if you wish
    
    Args:
      season_time (array of float) - contains the measurements per time step

    Returns:
      data_pattern (array of float) -  contains revised measurement values according 
                                  to the defined pattern
    """

    # Generate the values using an arbitrary pattern
    data_pattern = np.where(season_time < 0.4,
                    np.cos(season_time * 2 * np.pi),
                    1 / np.exp(3 * season_time))
    
    return data_pattern

def seasonality(time, period, amplitude=1, phase=0):
    """
    Repeats the same pattern at each period

    Args:
      time (array of int) - contains the time steps
      period (int) - number of time steps before the pattern repeats
      amplitude (int) - peak measured value in a period
      phase (int) - number of time steps to shift the measured values

    Returns:
      data_pattern (array of float) - seasonal data scaled by the defined amplitude
    """
    
    # Define the measured values per period
    season_time = ((time + phase) % period) / period

    # Generates the seasonal data scaled by the defined amplitude
    data_pattern = amplitude * seasonal_pattern(season_time)

    return data_pattern

def noise(time, noise_level=1, seed=None):
    """Generates a normally distributed noisy signal

    Args:
      time (array of int) - contains the time steps
      noise_level (float) - scaling factor for the generated signal
      seed (int) - number generator seed for repeatability

    Returns:
      noise (array of float) - the noisy signal
    """

    # Initialize the random number generator
    rnd = np.random.RandomState(seed)

    # Generate a random number for each time step and scale by the noise level
    noise = rnd.randn(len(time)) * noise_level
    
    return noise

# %%
# Parameters
time = np.arange(4 * 365 + 1, dtype="float32")
baseline = 10
amplitude = 40
slope = 0.05
noise_level = 5

# Create the series
series = baseline + trend(time, slope) + seasonality(time, period=365, amplitude=amplitude)

# Update with noise
series += noise(time, noise_level, seed=42)

# Plot the results
plot_series(time, series)

# %%
# Define the split time
split_time = 1000

# Get the train set 
time_train = time[:split_time]
x_train = series[:split_time]

# Get the validation set
time_valid = time[split_time:]
x_valid = series[split_time:]

# %%
# Parameters
window_size = 20
batch_size = 32
shuffle_buffer_size = 1000
EPOCHS = 300
PATIENCE = 5
MONITOR = 'val_loss'

def windowed_dataset(series, window_size, batch_size, shuffle_buffer=None, forward=1, mode='train'):
    """Generates dataset windows

    Args:
      series (array of float) - contains the values of the time series
      window_size (int) - the number of time steps to include in the feature
      batch_size (int) - the batch size
      shuffle_buffer(int) - buffer size to use for the shuffle method

    Returns:
      dataset (TF Dataset) - TF Dataset containing time windows
    """
  
    # Generate a TF Dataset from the series values
    dataset = tf.data.Dataset.from_tensor_slices(series)
    
    # Window the data but only take those with the specified size
    if mode == 'train':
        dataset = dataset.window(window_size + forward, shift=forward, drop_remainder=True)
    else:
        dataset = dataset.window(window_size, shift=forward, drop_remainder=True)
    
    # Flatten the windows by putting its elements in a single batch
    dataset = dataset.flat_map(lambda window: window.batch(window_size + forward))

    # Create tuples with features and labels 
    dataset = dataset.map(lambda window: (window[:-forward], window[-forward]))

    # Shuffle the windows
    if shuffle_buffer is not None:
        dataset = dataset.shuffle(shuffle_buffer)
    
    # Create batches of windows
    dataset = dataset.batch(batch_size).prefetch(tf.data.AUTOTUNE)
    
    return dataset


# Generate the dataset windows
train_dataset = windowed_dataset(x_train, window_size, batch_size, shuffle_buffer=shuffle_buffer_size)
test_dataset = windowed_dataset(x_valid, window_size, batch_size, shuffle_buffer=shuffle_buffer_size)
print(train_dataset, test_dataset)


# Print shapes of feature and label
for window in train_dataset.take(1):
    print(f'shape of feature: {window[0].shape}')
    print(f'shape of label: {window[1].shape}')
# Out:
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, None), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.float32, name=None))> <PrefetchDataset element_spec=(TensorSpec(shape=(None, None), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.float32, name=None))>
# shape of feature: (32, 20)
# shape of label: (32,)

# %%
MODEL_NAME = './models/TimeSeries_SimpleRNN_full_verse.h5'
# callbacks = [tf.keras.callbacks.LearningRateScheduler(lambda epoch: 1e-8 * 10**(epoch / 20))]
callbacks = [tf.keras.callbacks.ReduceLROnPlateau(monitor=MONITOR, factor=0.1, patience=PATIENCE, min_lr=1e-7)]
callbacks += [tf.keras.callbacks.ModelCheckpoint(MODEL_NAME, monitor=MONITOR, save_best_only=True)]
callbacks += [tf.keras.callbacks.EarlyStopping(monitor=MONITOR, patience=PATIENCE**2, restore_best_weights=True)]

# Build the Model
model = tf.keras.models.Sequential([
  tf.keras.layers.Lambda(lambda x: tf.expand_dims(x, axis=-1), input_shape=[window_size]),
  tf.keras.layers.SimpleRNN(42, return_sequences=True),
  tf.keras.layers.SimpleRNN(42),
  tf.keras.layers.Dense(1),
  tf.keras.layers.Lambda(lambda x: x * 100.0)
])

# Setup the training parameters
model.compile(
    # loss='mse',
    loss=tf.keras.losses.Huber(),
    optimizer=tf.keras.optimizers.Nadam(1e-3),
    metrics=['mae', 'mse', tf.keras.metrics.RootMeanSquaredError()]
)

# Print the model summary
print(model.summary())

history = model.fit(
    train_dataset,
    epochs=EPOCHS,
    batch_size=batch_size,
    validation_data=test_dataset,
    callbacks=callbacks
)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lambda_6 (Lambda)           (None, 20, 1)             0
#
#  simple_rnn_6 (SimpleRNN)    (None, 20, 42)            1848
#
#  simple_rnn_7 (SimpleRNN)    (None, 42)                3570
#
#  dense_3 (Dense)             (None, 1)                 43
#
#  lambda_7 (Lambda)           (None, 1)                 0
#
# =================================================================
# Total params: 5,461
# Trainable params: 5,461
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/300
# 31/31 [==============================] - 3s 69ms/step - loss: 15.0936 - mae: 15.5867 - mse: 458.1783 - root_mean_squared_error: 21.4051 - val_loss: 17.6820 - val_mae: 18.1777 - val_mse: 457.4695 - val_root_mean_squared_error: 21.3885 - lr: 0.0010
# Epoch 2/300
# 31/31 [==============================] - 2s 49ms/step - loss: 11.0979 - mae: 11.5915 - mse: 214.4895 - root_mean_squared_error: 14.6455 - val_loss: 18.1505 - val_mae: 18.6455 - val_mse: 471.2323 - val_root_mean_squared_error: 21.7079 - lr: 0.0010
# Epoch 3/300
# 31/31 [==============================] - 2s 54ms/step - loss: 10.2222 - mae: 10.7136 - mse: 180.1459 - root_mean_squared_error: 13.4218 - val_loss: 20.7172 - val_mae: 21.2156 - val_mse: 565.7383 - val_root_mean_squared_error: 23.7853 - lr: 0.0010
# Epoch 4/300
# 31/31 [==============================] - 2s 55ms/step - loss: 8.2721 - mae: 8.7621 - mse: 125.2266 - root_mean_squared_error: 11.1905 - val_loss: 14.8302 - val_mae: 15.3266 - val_mse: 329.3334 - val_root_mean_squared_error: 18.1475 - lr: 0.0010
# Epoch 5/300
# 31/31 [==============================] - 2s 55ms/step - loss: 7.9691 - mae: 8.4600 - mse: 114.1785 - root_mean_squared_error: 10.6854 - val_loss: 7.3818 - val_mae: 7.8703 - val_mse: 105.1777 - val_root_mean_squared_error: 10.2556 - lr: 0.0010
# Epoch 6/300
# 31/31 [==============================] - 2s 51ms/step - loss: 7.3492 - mae: 7.8380 - mse: 100.3060 - root_mean_squared_error: 10.0153 - val_loss: 9.7468 - val_mae: 10.2384 - val_mse: 169.2913 - val_root_mean_squared_error: 13.0112 - lr: 0.0010
# Epoch 7/300
# 31/31 [==============================] - 2s 53ms/step - loss: 6.6685 - mae: 7.1527 - mse: 87.7803 - root_mean_squared_error: 9.3691 - val_loss: 7.2753 - val_mae: 7.7588 - val_mse: 95.9344 - val_root_mean_squared_error: 9.7946 - lr: 0.0010
# Epoch 8/300
# 31/31 [==============================] - 2s 58ms/step - loss: 7.2394 - mae: 7.7250 - mse: 95.8052 - root_mean_squared_error: 9.7880 - val_loss: 7.0787 - val_mae: 7.5621 - val_mse: 101.7161 - val_root_mean_squared_error: 10.0854 - lr: 0.0010
# Epoch 9/300
# 31/31 [==============================] - 2s 54ms/step - loss: 6.4381 - mae: 6.9210 - mse: 80.5571 - root_mean_squared_error: 8.9754 - val_loss: 9.0182 - val_mae: 9.5071 - val_mse: 149.0372 - val_root_mean_squared_error: 12.2081 - lr: 0.0010
# Epoch 10/300
# 31/31 [==============================] - 2s 56ms/step - loss: 6.6189 - mae: 7.1034 - mse: 82.1967 - root_mean_squared_error: 9.0662 - val_loss: 6.1640 - val_mae: 6.6453 - val_mse: 77.8007 - val_root_mean_squared_error: 8.8205 - lr: 0.0010
# Epoch 11/300
# 31/31 [==============================] - 2s 57ms/step - loss: 6.5789 - mae: 7.0633 - mse: 84.8889 - root_mean_squared_error: 9.2135 - val_loss: 7.8078 - val_mae: 8.2930 - val_mse: 120.2412 - val_root_mean_squared_error: 10.9655 - lr: 0.0010
# Epoch 12/300
# 31/31 [==============================] - 2s 55ms/step - loss: 6.6736 - mae: 7.1589 - mse: 81.9966 - root_mean_squared_error: 9.0552 - val_loss: 7.6567 - val_mae: 8.1509 - val_mse: 115.0299 - val_root_mean_squared_error: 10.7252 - lr: 0.0010
# Epoch 13/300
# 31/31 [==============================] - 2s 52ms/step - loss: 5.7724 - mae: 6.2514 - mse: 66.0772 - root_mean_squared_error: 8.1288 - val_loss: 8.5921 - val_mae: 9.0799 - val_mse: 137.1593 - val_root_mean_squared_error: 11.7115 - lr: 0.0010
# Epoch 14/300
# 31/31 [==============================] - 2s 53ms/step - loss: 5.6749 - mae: 6.1615 - mse: 63.6642 - root_mean_squared_error: 7.9790 - val_loss: 6.6726 - val_mae: 7.1544 - val_mse: 92.4904 - val_root_mean_squared_error: 9.6172 - lr: 0.0010
# Epoch 15/300
# 31/31 [==============================] - 2s 52ms/step - loss: 5.5989 - mae: 6.0789 - mse: 64.8022 - root_mean_squared_error: 8.0500 - val_loss: 7.3204 - val_mae: 7.8055 - val_mse: 107.5249 - val_root_mean_squared_error: 10.3694 - lr: 0.0010
# Epoch 16/300
# 31/31 [==============================] - 2s 53ms/step - loss: 4.4886 - mae: 4.9673 - mse: 45.1876 - root_mean_squared_error: 6.7222 - val_loss: 6.2421 - val_mae: 6.7228 - val_mse: 84.0439 - val_root_mean_squared_error: 9.1675 - lr: 1.0000e-04
# Epoch 17/300
# 31/31 [==============================] - 2s 55ms/step - loss: 4.4068 - mae: 4.8846 - mse: 43.3764 - root_mean_squared_error: 6.5861 - val_loss: 6.1411 - val_mae: 6.6205 - val_mse: 81.5852 - val_root_mean_squared_error: 9.0325 - lr: 1.0000e-04
# Epoch 18/300
# 31/31 [==============================] - 2s 55ms/step - loss: 4.3563 - mae: 4.8320 - mse: 42.3618 - root_mean_squared_error: 6.5086 - val_loss: 6.5184 - val_mae: 7.0009 - val_mse: 90.1328 - val_root_mean_squared_error: 9.4938 - lr: 1.0000e-04
# Epoch 19/300
# 31/31 [==============================] - 2s 55ms/step - loss: 4.3080 - mae: 4.7815 - mse: 42.2162 - root_mean_squared_error: 6.4974 - val_loss: 5.9266 - val_mae: 6.4081 - val_mse: 76.8532 - val_root_mean_squared_error: 8.7666 - lr: 1.0000e-04
# Epoch 20/300
# 31/31 [==============================] - 2s 55ms/step - loss: 4.3025 - mae: 4.7781 - mse: 41.7059 - root_mean_squared_error: 6.4580 - val_loss: 6.0339 - val_mae: 6.5142 - val_mse: 79.5446 - val_root_mean_squared_error: 8.9188 - lr: 1.0000e-04
# Epoch 21/300
# 31/31 [==============================] - 2s 56ms/step - loss: 4.2675 - mae: 4.7430 - mse: 41.4975 - root_mean_squared_error: 6.4419 - val_loss: 5.8814 - val_mae: 6.3633 - val_mse: 76.0891 - val_root_mean_squared_error: 8.7229 - lr: 1.0000e-04
# Epoch 22/300
# 31/31 [==============================] - 2s 50ms/step - loss: 4.2707 - mae: 4.7483 - mse: 41.3588 - root_mean_squared_error: 6.4311 - val_loss: 6.0235 - val_mae: 6.5024 - val_mse: 79.2152 - val_root_mean_squared_error: 8.9003 - lr: 1.0000e-04
# Epoch 23/300
# 31/31 [==============================] - 2s 52ms/step - loss: 4.2485 - mae: 4.7229 - mse: 41.1830 - root_mean_squared_error: 6.4174 - val_loss: 6.0468 - val_mae: 6.5238 - val_mse: 79.9686 - val_root_mean_squared_error: 8.9425 - lr: 1.0000e-04
# Epoch 24/300
# 31/31 [==============================] - 2s 59ms/step - loss: 4.2465 - mae: 4.7248 - mse: 41.0932 - root_mean_squared_error: 6.4104 - val_loss: 5.7878 - val_mae: 6.2729 - val_mse: 73.9678 - val_root_mean_squared_error: 8.6005 - lr: 1.0000e-04
# Epoch 25/300
# 31/31 [==============================] - 2s 56ms/step - loss: 4.2537 - mae: 4.7288 - mse: 41.0332 - root_mean_squared_error: 6.4057 - val_loss: 5.5420 - val_mae: 6.0243 - val_mse: 67.9434 - val_root_mean_squared_error: 8.2428 - lr: 1.0000e-04
# Epoch 26/300
# 31/31 [==============================] - 2s 54ms/step - loss: 4.2105 - mae: 4.6854 - mse: 40.5712 - root_mean_squared_error: 6.3695 - val_loss: 5.5229 - val_mae: 6.0043 - val_mse: 67.8034 - val_root_mean_squared_error: 8.2343 - lr: 1.0000e-04
# Epoch 27/300
# 31/31 [==============================] - 2s 50ms/step - loss: 4.2487 - mae: 4.7248 - mse: 41.0260 - root_mean_squared_error: 6.4052 - val_loss: 5.9863 - val_mae: 6.4631 - val_mse: 78.5735 - val_root_mean_squared_error: 8.8642 - lr: 1.0000e-04
# Epoch 28/300
# 31/31 [==============================] - 2s 55ms/step - loss: 4.2226 - mae: 4.6978 - mse: 40.7031 - root_mean_squared_error: 6.3799 - val_loss: 5.4875 - val_mae: 5.9689 - val_mse: 66.6495 - val_root_mean_squared_error: 8.1639 - lr: 1.0000e-04
# Epoch 29/300
# 31/31 [==============================] - 2s 56ms/step - loss: 4.2026 - mae: 4.6795 - mse: 40.8251 - root_mean_squared_error: 6.3895 - val_loss: 5.6693 - val_mae: 6.1543 - val_mse: 71.3339 - val_root_mean_squared_error: 8.4459 - lr: 1.0000e-04
# Epoch 30/300
# 31/31 [==============================] - 2s 56ms/step - loss: 4.1925 - mae: 4.6676 - mse: 40.3025 - root_mean_squared_error: 6.3484 - val_loss: 5.4316 - val_mae: 5.9108 - val_mse: 65.3344 - val_root_mean_squared_error: 8.0830 - lr: 1.0000e-04
# Epoch 31/300
# 31/31 [==============================] - 2s 54ms/step - loss: 4.1924 - mae: 4.6679 - mse: 40.6591 - root_mean_squared_error: 6.3765 - val_loss: 5.3665 - val_mae: 5.8420 - val_mse: 63.7115 - val_root_mean_squared_error: 7.9819 - lr: 1.0000e-04
# Epoch 32/300
# 31/31 [==============================] - 2s 52ms/step - loss: 4.1914 - mae: 4.6649 - mse: 40.4434 - root_mean_squared_error: 6.3595 - val_loss: 5.4846 - val_mae: 5.9675 - val_mse: 66.9776 - val_root_mean_squared_error: 8.1840 - lr: 1.0000e-04
# Epoch 33/300
# 31/31 [==============================] - 2s 56ms/step - loss: 4.2030 - mae: 4.6779 - mse: 40.3251 - root_mean_squared_error: 6.3502 - val_loss: 5.2900 - val_mae: 5.7686 - val_mse: 61.0775 - val_root_mean_squared_error: 7.8152 - lr: 1.0000e-04
# Epoch 34/300
# 31/31 [==============================] - 2s 53ms/step - loss: 4.2001 - mae: 4.6722 - mse: 40.8699 - root_mean_squared_error: 6.3930 - val_loss: 5.7038 - val_mae: 6.1857 - val_mse: 72.1708 - val_root_mean_squared_error: 8.4953 - lr: 1.0000e-04
# Epoch 35/300
# 31/31 [==============================] - 2s 53ms/step - loss: 4.1767 - mae: 4.6508 - mse: 40.2388 - root_mean_squared_error: 6.3434 - val_loss: 6.1158 - val_mae: 6.5928 - val_mse: 80.9891 - val_root_mean_squared_error: 8.9994 - lr: 1.0000e-04
# Epoch 36/300
# 31/31 [==============================] - 2s 52ms/step - loss: 4.1835 - mae: 4.6583 - mse: 40.4678 - root_mean_squared_error: 6.3614 - val_loss: 5.3423 - val_mae: 5.8191 - val_mse: 63.6115 - val_root_mean_squared_error: 7.9757 - lr: 1.0000e-04
# Epoch 37/300
# 31/31 [==============================] - 2s 55ms/step - loss: 4.1813 - mae: 4.6552 - mse: 40.3652 - root_mean_squared_error: 6.3534 - val_loss: 5.5059 - val_mae: 5.9875 - val_mse: 67.7377 - val_root_mean_squared_error: 8.2303 - lr: 1.0000e-04
# Epoch 38/300
# 31/31 [==============================] - 2s 53ms/step - loss: 4.1461 - mae: 4.6174 - mse: 40.0660 - root_mean_squared_error: 6.3298 - val_loss: 5.8301 - val_mae: 6.3062 - val_mse: 74.8637 - val_root_mean_squared_error: 8.6524 - lr: 1.0000e-04
# Epoch 39/300
# 31/31 [==============================] - 2s 52ms/step - loss: 4.1425 - mae: 4.6152 - mse: 39.9257 - root_mean_squared_error: 6.3187 - val_loss: 5.5132 - val_mae: 5.9944 - val_mse: 67.8871 - val_root_mean_squared_error: 8.2394 - lr: 1.0000e-05
# Epoch 40/300
# 31/31 [==============================] - 2s 54ms/step - loss: 4.1114 - mae: 4.5828 - mse: 39.5487 - root_mean_squared_error: 6.2888 - val_loss: 5.4376 - val_mae: 5.9197 - val_mse: 66.1255 - val_root_mean_squared_error: 8.1318 - lr: 1.0000e-05
# Epoch 41/300
# 31/31 [==============================] - 2s 55ms/step - loss: 4.1036 - mae: 4.5714 - mse: 39.3572 - root_mean_squared_error: 6.2735 - val_loss: 5.4865 - val_mae: 5.9680 - val_mse: 67.2939 - val_root_mean_squared_error: 8.2033 - lr: 1.0000e-05
# Epoch 42/300
# 31/31 [==============================] - 2s 53ms/step - loss: 4.1030 - mae: 4.5724 - mse: 39.4235 - root_mean_squared_error: 6.2788 - val_loss: 5.4647 - val_mae: 5.9463 - val_mse: 66.7735 - val_root_mean_squared_error: 8.1715 - lr: 1.0000e-05
# Epoch 43/300
# 31/31 [==============================] - 2s 51ms/step - loss: 4.0984 - mae: 4.5666 - mse: 39.3840 - root_mean_squared_error: 6.2757 - val_loss: 5.4308 - val_mae: 5.9128 - val_mse: 65.9885 - val_root_mean_squared_error: 8.1233 - lr: 1.0000e-05
# Epoch 44/300
# 31/31 [==============================] - 2s 52ms/step - loss: 4.0939 - mae: 4.5614 - mse: 39.3352 - root_mean_squared_error: 6.2718 - val_loss: 5.4304 - val_mae: 5.9125 - val_mse: 65.9815 - val_root_mean_squared_error: 8.1229 - lr: 1.0000e-06
# Epoch 45/300
# 31/31 [==============================] - 2s 50ms/step - loss: 4.0937 - mae: 4.5610 - mse: 39.3279 - root_mean_squared_error: 6.2712 - val_loss: 5.4290 - val_mae: 5.9110 - val_mse: 65.9482 - val_root_mean_squared_error: 8.1208 - lr: 1.0000e-06
# Epoch 46/300
# 31/31 [==============================] - 2s 52ms/step - loss: 4.0941 - mae: 4.5615 - mse: 39.3328 - root_mean_squared_error: 6.2716 - val_loss: 5.4309 - val_mae: 5.9129 - val_mse: 65.9940 - val_root_mean_squared_error: 8.1237 - lr: 1.0000e-06
# Epoch 47/300
# 31/31 [==============================] - 2s 52ms/step - loss: 4.0936 - mae: 4.5610 - mse: 39.3291 - root_mean_squared_error: 6.2713 - val_loss: 5.4281 - val_mae: 5.9101 - val_mse: 65.9256 - val_root_mean_squared_error: 8.1195 - lr: 1.0000e-06
# Epoch 48/300
# 31/31 [==============================] - 2s 54ms/step - loss: 4.0934 - mae: 4.5607 - mse: 39.3264 - root_mean_squared_error: 6.2711 - val_loss: 5.4312 - val_mae: 5.9132 - val_mse: 66.0010 - val_root_mean_squared_error: 8.1241 - lr: 1.0000e-06
# Epoch 49/300
# 31/31 [==============================] - 2s 54ms/step - loss: 4.0929 - mae: 4.5601 - mse: 39.3210 - root_mean_squared_error: 6.2706 - val_loss: 5.4314 - val_mae: 5.9134 - val_mse: 66.0059 - val_root_mean_squared_error: 8.1244 - lr: 1.0000e-07
# Epoch 50/300
# 31/31 [==============================] - 2s 50ms/step - loss: 4.0929 - mae: 4.5601 - mse: 39.3208 - root_mean_squared_error: 6.2706 - val_loss: 5.4310 - val_mae: 5.9130 - val_mse: 65.9961 - val_root_mean_squared_error: 8.1238 - lr: 1.0000e-07
# Epoch 51/300
# 31/31 [==============================] - 2s 54ms/step - loss: 4.0928 - mae: 4.5601 - mse: 39.3203 - root_mean_squared_error: 6.2706 - val_loss: 5.4307 - val_mae: 5.9126 - val_mse: 65.9884 - val_root_mean_squared_error: 8.1233 - lr: 1.0000e-07
# Epoch 52/300
# 31/31 [==============================] - 2s 51ms/step - loss: 4.0928 - mae: 4.5601 - mse: 39.3202 - root_mean_squared_error: 6.2706 - val_loss: 5.4307 - val_mae: 5.9127 - val_mse: 65.9893 - val_root_mean_squared_error: 8.1234 - lr: 1.0000e-07
# Epoch 53/300
# 31/31 [==============================] - 2s 52ms/step - loss: 4.0928 - mae: 4.5600 - mse: 39.3197 - root_mean_squared_error: 6.2705 - val_loss: 5.4303 - val_mae: 5.9123 - val_mse: 65.9804 - val_root_mean_squared_error: 8.1228 - lr: 1.0000e-07
# Epoch 54/300
# 31/31 [==============================] - 2s 52ms/step - loss: 4.0928 - mae: 4.5601 - mse: 39.3196 - root_mean_squared_error: 6.2705 - val_loss: 5.4300 - val_mae: 5.9120 - val_mse: 65.9728 - val_root_mean_squared_error: 8.1224 - lr: 1.0000e-07
# Epoch 55/300
# 31/31 [==============================] - 2s 51ms/step - loss: 4.0929 - mae: 4.5601 - mse: 39.3197 - root_mean_squared_error: 6.2705 - val_loss: 5.4297 - val_mae: 5.9117 - val_mse: 65.9664 - val_root_mean_squared_error: 8.1220 - lr: 1.0000e-07
# Epoch 56/300
# 31/31 [==============================] - 2s 52ms/step - loss: 4.0928 - mae: 4.5600 - mse: 39.3189 - root_mean_squared_error: 6.2705 - val_loss: 5.4293 - val_mae: 5.9113 - val_mse: 65.9568 - val_root_mean_squared_error: 8.1214 - lr: 1.0000e-07
# Epoch 57/300
# 31/31 [==============================] - 2s 53ms/step - loss: 4.0928 - mae: 4.5600 - mse: 39.3197 - root_mean_squared_error: 6.2705 - val_loss: 5.4299 - val_mae: 5.9119 - val_mse: 65.9705 - val_root_mean_squared_error: 8.1222 - lr: 1.0000e-07
# Epoch 58/300
# 31/31 [==============================] - 2s 53ms/step - loss: 4.0928 - mae: 4.5600 - mse: 39.3198 - root_mean_squared_error: 6.2706 - val_loss: 5.4291 - val_mae: 5.9111 - val_mse: 65.9513 - val_root_mean_squared_error: 8.1210 - lr: 1.0000e-07

# %%
hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()


hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch

plt.plot(history.history['loss'][-20:])
plt.plot(history.history['val_loss'][-20:])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# Reduce the original series
forecast_series = series[split_time - window_size:-1]

# Use helper function to generate predictions
forecast_dataset = windowed_dataset(forecast_series, window_size, batch_size, mode='pred')
forecast = model.predict(forecast_dataset)

# Drop single dimensional axis
results = forecast.squeeze()

# Compute the MSE and MAE
print(tf.keras.metrics.mean_squared_error(x_valid, results).numpy())
print(tf.keras.metrics.mean_absolute_error(x_valid, results).numpy())

# Plot the results
plot_series(time_valid, (x_valid, results))
# Out:
# 15/15 [==============================] - 0s 14ms/step
# 63.481846
# 5.766372
